# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# # Imports

# %%
from twitterscraper import query_tweets
import datetime as dt 
import pandas as pd
from tqdm import tqdm

import matplotlib.pyplot as plt 
import seaborn as sns

from textblob import TextBlob
import re
import string
import unicodedata
import contractions
import inflect

import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import LancasterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize

import warnings
warnings.filterwarnings('ignore')

from string import punctuation 
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import preprocessing

try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
import urllib

import time

from nltk.sentiment.vader import SentimentIntensityAnalyzer

import project_lib
import multiprocessing
from multiprocessing import Pool
import os

import unicodecsv as csv
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}

# %% [markdown]
# # Functions (also available in project_lib.py)
# Define functions to request Twitter data, clean it and extract sentiment out of it.
# The project_lib.py is meant for the multiprocessing on windows.

# %%
def request_twitter(company, start_date, end_date):
    query = company + ' -filter:retweets -filter:replies'
    delta = dt.timedelta(days=7)
    twts_raw = pd.DataFrame()
    twts_df = pd.DataFrame()
    EndDT = start_date + delta
    BeginDT = start_date
    while EndDT <= EndDate:
    
        tweets = query_tweets(query, limit=None, begindate=BeginDT,
                              enddate=EndDT, lang='en')
        tweets_df = pd.DataFrame(t.__dict__ for t in tweets)
        twts_df = twts_df.append(tweets_df)
    
    
        if (EndDate - EndDT) > delta:
            BeginDT = BeginDT + delta
            EndDT = EndDT + delta
        else:
            BeginDT = BeginDT + delta
            EndDT = EndDate
            if BeginDT > EndDT:
                break
    
    twts_raw = twts_df        
    twts_df = twts_df.drop_duplicates(subset=['tweet_id'])
    twts_df = twts_df.set_index('tweet_id')
    twts_df = twts_df.sort_index()
    
    return twts_df, twts_raw

''' twitterscraper allows to retrieve historical twitter data without using the
    Twitter API thus no need to have a premium account '''
    
''' begindate starts at date '''
''' enddate ends at date-1 '''


def get_text_from_image(url):
    local_filename, headers = urllib.request.urlretrieve(url)
    image_text = pytesseract.image_to_string(local_filename)
    print('Text: ' + image_text + ' retrieve from image.')
    return image_text

def retrieve_attachement_data(tweet):
    for match in re.finditer(r'((www\.[^\s]+)|(https?://[^\s]+))', tweet):
        url = tweet[match.start():match.end()]
        # use try in order to catch errors due to bad links
        try:
            # Retrieve link info
            #print('Testing url: ' + url)
            u = urllib.request.urlopen(url)
            result = u.info()
            
            # if the format is the one desired process it else skip it
            content_type = result.get_content_type()
            if len(content_type) < 5:
                print('When retrieving url ' + url + ' found content type ' + result + " that will not be analysed.")
            
            elif content_type[:5] == 'image': # match image/gif,image/jpeg,image/png
                tweet = tweet + ' ' + get_text_from_image(url)
            
            #elif content_type == ('application/pdf'):
                #tweet = tweet + ' ' + get_text_from_pdf(url)
                
        except urllib.error.HTTPError as e:
            print('An HTTPError has been raised, code ' + str(e.code) + '. Passing to the next step.')
        except urllib.error.URLError as e:
            print('An URLError has been raised, reason ' + str(e.reason) + '. Passing to the next step.')
        except ConnectionResetError:
            print('A ConnectionResetError has been raised. Passing to the next step.')

    return tweet

def download_attachement(tweet):
    
    return tweet

def remove_url(tweet):
    tweet = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+))', '', tweet)
    return tweet

def remove_user(tweet):
    tweet = re.sub('@[^\s]+', '', tweet)
    return tweet

def remove_hashtags(tweet):
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    return tweet

def contract_words(tweet):
    tweet = contractions.fix(tweet)
    return tweet

def remove_non_ascii(tweet):
    tweet = unicodedata.normalize('NFKD', tweet).encode('ascii', 'ignore').\
    decode('utf-8', 'ignore')
    return tweet

def remove_characters(tweet):
    tweet = re.sub(r'[^a-zA-Z0-9]', ' ', tweet)
    return tweet

def lowercase(tweet):
    tweet = tweet.lower()
    return tweet

def remove_punctuation(tweet):
    tweet =re.sub(r'[^\w\s]', '', tweet)
    return tweet

def replace_numbers(tweet):
    p = inflect.engine()
    new_words = []
    for word in tweet.split():
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return ' '.join(new_words)

def remove_stopwords(tweet):
    clean_mess = [word for word in tweet.split() if word.lower() not in stopwords.words('english')]
    clean_tweet = ' '.join(clean_mess)
    return clean_tweet

def normalization(tweet):
    lem = WordNetLemmatizer()
    normalized_tweet = []
    for word in tweet.split():
        normalized_text = lem.lemmatize(word, pos='v')
        normalized_tweet.append(normalized_text)
    return ' '.join(normalized_tweet)

def tweet_normalized(tweet):
    tweet = remove_url(tweet)
    tweet = remove_user(tweet)
    tweet = remove_hashtags(tweet)
    tweet = contract_words(tweet)
    tweet = remove_non_ascii(tweet)
    tweet = remove_characters(tweet)
    tweet = lowercase(tweet)
    tweet = remove_punctuation(tweet)
    tweet = replace_numbers(tweet)
    tweet = remove_stopwords(tweet)
    tweet = normalization(tweet)
    return tweet


def oldmultiprocess_execution(timestamp,img_urls,links,replies,retweets,text,tweet_id,comp):
    try:
        '''Initialize Sentiment Analyzer'''
        sid = SentimentIntensityAnalyzer()
        tweet_text = text
        if type(img_urls) is str:
            tweet_text = str(img_urls).replace('[\'','').replace('\']',' ') + ' ' + tweet_text
        if type(links) is str:
            tweet_text = str(links).replace('[\'','').replace('\']',' ') + ' ' + tweet_text
        #tweet_text = retrieve_attachement_data(tweet_text)
        tweet_text = tweet_normalized(tweet_text)
        polarity = sid.polarity_scores(tweet_text)
        returned_data = {'tweet_id':tweet_id, 'timestamp':timestamp, 'replies':replies, 'retweets':retweets,'clean_tweet':tweet_text,'Comp':polarity['compound'],'Negative':polarity['neg'],'Neutral':polarity['neu'],'Positive':polarity['pos']}
    except:
        print('An error ocurred, skipping the line ' + str(tweet_id) + ' on timestamp ' + str(timestamp))
        returned_data = {}
    return returned_data

# %% [markdown]
# # Request Twitter Data
#
# Loop to request Twitter data of "names" in list companies. The loop will save data in 2 csv files: one csv with RAW data and the other: sorted, with removed duplicates and data in first column

# %%
start = time.time()
#%%

''' REQUEST TWITTER DATA ''' 

'''LOOP TO REQUEST TWITTER DATA OF "NAMES" IN LIST companies. LOOP WILL SAVE DATA 
    IN 2 CSV FILES: ONE CSV WITH RAW DATA AND THE OTHER: SORTED, REMOVING 
    DUPLICATES, AND DATA IN FIRST COLUMN'''

###############################################################################
###############################################################################
''' data is taken as of BeginDate until (EndDate - 1) '''
BeginDate = dt.date(2017,1,1) 
EndDate = dt.date(2020,4,1)
'''companies = ['Microsoft', 'Apple', 'Mastercard','Intel Corp', 
             'Cisco Systems', 'Adobe', 'Nvidia',
             'Salesforce', 'PayPal', 'Oracle', '#SP500']'''
companies = ['Paypal']
###############################################################################
###############################################################################
             
start_year = BeginDate.strftime('%Y%m%d')
end_year = EndDate.strftime('%Y%m%d')

for company in companies:
    temp_df = pd.DataFrame()
    temp_raw = []
    temp_df, temp_raw = request_twitter(company, BeginDate, EndDate)
    filename_df = company+'_'+start_year+'_'+end_year+'.csv'
    filename_raw = company+'_raw_'+start_year+'_'+end_year+'.csv'
    temp_df = temp_df.replace(r'\n',' ', regex=True)
    temp_raw = temp_raw.replace(r'\n',' ', regex=True)
    temp_df.to_csv(filename_df, sep = "|", header=True, index=True)
    temp_raw.to_csv(filename_raw, sep = "|",header=True,index=False)

elapsed = time.time() - start
print(f"Elapsed time: {elapsed}")
# Out:
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-01-01 until:2017-01-02', 'Paypal -filter:retweets -filter:replies since:2017-01-02 until:2017-01-03', 'Paypal -filter:retweets -filter:replies since:2017-01-03 until:2017-01-04', 'Paypal -filter:retweets -filter:replies since:2017-01-04 until:2017-01-05', 'Paypal -filter:retweets -filter:replies since:2017-01-05 until:2017-01-06', 'Paypal -filter:retweets -filter:replies since:2017-01-06 until:2017-01-07', 'Paypal -filter:retweets -filter:replies since:2017-01-07 until:2017-01-08']
# INFO: Got 2108 tweets (2108 new).
# INFO: Got 4555 tweets (2447 new).
# INFO: Got 6917 tweets (2362 new).
# INFO: Got 9260 tweets (2343 new).
# INFO: Got 11545 tweets (2285 new).
# INFO: Got 13910 tweets (2365 new).
# INFO: Got 16248 tweets (2338 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-01-08 until:2017-01-09', 'Paypal -filter:retweets -filter:replies since:2017-01-09 until:2017-01-10', 'Paypal -filter:retweets -filter:replies since:2017-01-10 until:2017-01-11', 'Paypal -filter:retweets -filter:replies since:2017-01-11 until:2017-01-12', 'Paypal -filter:retweets -filter:replies since:2017-01-12 until:2017-01-13', 'Paypal -filter:retweets -filter:replies since:2017-01-13 until:2017-01-14', 'Paypal -filter:retweets -filter:replies since:2017-01-14 until:2017-01-15']
# INFO: Got 1742 tweets (1742 new).
# INFO: Got 3456 tweets (1714 new).
# INFO: Got 5417 tweets (1961 new).
# INFO: Got 7047 tweets (1630 new).
# INFO: Got 8986 tweets (1939 new).
# INFO: Got 10720 tweets (1734 new).
# INFO: Got 12707 tweets (1987 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-01-15 until:2017-01-16', 'Paypal -filter:retweets -filter:replies since:2017-01-16 until:2017-01-17', 'Paypal -filter:retweets -filter:replies since:2017-01-17 until:2017-01-18', 'Paypal -filter:retweets -filter:replies since:2017-01-18 until:2017-01-19', 'Paypal -filter:retweets -filter:replies since:2017-01-19 until:2017-01-20', 'Paypal -filter:retweets -filter:replies since:2017-01-20 until:2017-01-21', 'Paypal -filter:retweets -filter:replies since:2017-01-21 until:2017-01-22']
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 118 tweets (19 new).
# INFO: Got 138 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-01-22 until:2017-01-23', 'Paypal -filter:retweets -filter:replies since:2017-01-23 until:2017-01-24', 'Paypal -filter:retweets -filter:replies since:2017-01-24 until:2017-01-25', 'Paypal -filter:retweets -filter:replies since:2017-01-25 until:2017-01-26', 'Paypal -filter:retweets -filter:replies since:2017-01-26 until:2017-01-27', 'Paypal -filter:retweets -filter:replies since:2017-01-27 until:2017-01-28', 'Paypal -filter:retweets -filter:replies since:2017-01-28 until:2017-01-29']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-01-29 until:2017-01-30', 'Paypal -filter:retweets -filter:replies since:2017-01-30 until:2017-01-31', 'Paypal -filter:retweets -filter:replies since:2017-01-31 until:2017-02-01', 'Paypal -filter:retweets -filter:replies since:2017-02-01 until:2017-02-02', 'Paypal -filter:retweets -filter:replies since:2017-02-02 until:2017-02-03', 'Paypal -filter:retweets -filter:replies since:2017-02-03 until:2017-02-04', 'Paypal -filter:retweets -filter:replies since:2017-02-04 until:2017-02-05']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-02-05 until:2017-02-06', 'Paypal -filter:retweets -filter:replies since:2017-02-06 until:2017-02-07', 'Paypal -filter:retweets -filter:replies since:2017-02-07 until:2017-02-08', 'Paypal -filter:retweets -filter:replies since:2017-02-08 until:2017-02-09', 'Paypal -filter:retweets -filter:replies since:2017-02-09 until:2017-02-10', 'Paypal -filter:retweets -filter:replies since:2017-02-10 until:2017-02-11', 'Paypal -filter:retweets -filter:replies since:2017-02-11 until:2017-02-12']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 160 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-02-12 until:2017-02-13', 'Paypal -filter:retweets -filter:replies since:2017-02-13 until:2017-02-14', 'Paypal -filter:retweets -filter:replies since:2017-02-14 until:2017-02-15', 'Paypal -filter:retweets -filter:replies since:2017-02-15 until:2017-02-16', 'Paypal -filter:retweets -filter:replies since:2017-02-16 until:2017-02-17', 'Paypal -filter:retweets -filter:replies since:2017-02-17 until:2017-02-18', 'Paypal -filter:retweets -filter:replies since:2017-02-18 until:2017-02-19']
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 98 tweets (19 new).
# INFO: Got 115 tweets (17 new).
# INFO: Got 155 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-02-19 until:2017-02-20', 'Paypal -filter:retweets -filter:replies since:2017-02-20 until:2017-02-21', 'Paypal -filter:retweets -filter:replies since:2017-02-21 until:2017-02-22', 'Paypal -filter:retweets -filter:replies since:2017-02-22 until:2017-02-23', 'Paypal -filter:retweets -filter:replies since:2017-02-23 until:2017-02-24', 'Paypal -filter:retweets -filter:replies since:2017-02-24 until:2017-02-25', 'Paypal -filter:retweets -filter:replies since:2017-02-25 until:2017-02-26']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-02-26 until:2017-02-27', 'Paypal -filter:retweets -filter:replies since:2017-02-27 until:2017-02-28', 'Paypal -filter:retweets -filter:replies since:2017-02-28 until:2017-03-01', 'Paypal -filter:retweets -filter:replies since:2017-03-01 until:2017-03-02', 'Paypal -filter:retweets -filter:replies since:2017-03-02 until:2017-03-03', 'Paypal -filter:retweets -filter:replies since:2017-03-03 until:2017-03-04', 'Paypal -filter:retweets -filter:replies since:2017-03-04 until:2017-03-05']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-03-05 until:2017-03-06', 'Paypal -filter:retweets -filter:replies since:2017-03-06 until:2017-03-07', 'Paypal -filter:retweets -filter:replies since:2017-03-07 until:2017-03-08', 'Paypal -filter:retweets -filter:replies since:2017-03-08 until:2017-03-09', 'Paypal -filter:retweets -filter:replies since:2017-03-09 until:2017-03-10', 'Paypal -filter:retweets -filter:replies since:2017-03-10 until:2017-03-11', 'Paypal -filter:retweets -filter:replies since:2017-03-11 until:2017-03-12']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 139 tweets (40 new).
# INFO: Got 177 tweets (38 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-03-12 until:2017-03-13', 'Paypal -filter:retweets -filter:replies since:2017-03-13 until:2017-03-14', 'Paypal -filter:retweets -filter:replies since:2017-03-14 until:2017-03-15', 'Paypal -filter:retweets -filter:replies since:2017-03-15 until:2017-03-16', 'Paypal -filter:retweets -filter:replies since:2017-03-16 until:2017-03-17', 'Paypal -filter:retweets -filter:replies since:2017-03-17 until:2017-03-18', 'Paypal -filter:retweets -filter:replies since:2017-03-18 until:2017-03-19']
# INFO: Got 2628 tweets (2628 new).
# INFO: Got 5231 tweets (2603 new).
# INFO: Got 8317 tweets (3086 new).
# INFO: Got 11315 tweets (2998 new).
# INFO: Got 14418 tweets (3103 new).
# INFO: Got 17471 tweets (3053 new).
# INFO: Got 20474 tweets (3003 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-03-19 until:2017-03-20', 'Paypal -filter:retweets -filter:replies since:2017-03-20 until:2017-03-21', 'Paypal -filter:retweets -filter:replies since:2017-03-21 until:2017-03-22', 'Paypal -filter:retweets -filter:replies since:2017-03-22 until:2017-03-23', 'Paypal -filter:retweets -filter:replies since:2017-03-23 until:2017-03-24', 'Paypal -filter:retweets -filter:replies since:2017-03-24 until:2017-03-25', 'Paypal -filter:retweets -filter:replies since:2017-03-25 until:2017-03-26']
# INFO: Got 2487 tweets (2487 new).
# INFO: Got 4984 tweets (2497 new).
# INFO: Got 7856 tweets (2872 new).
# INFO: Got 10524 tweets (2668 new).
# INFO: Got 13359 tweets (2835 new).
# INFO: Got 15832 tweets (2473 new).
# INFO: Got 18688 tweets (2856 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-03-26 until:2017-03-27', 'Paypal -filter:retweets -filter:replies since:2017-03-27 until:2017-03-28', 'Paypal -filter:retweets -filter:replies since:2017-03-28 until:2017-03-29', 'Paypal -filter:retweets -filter:replies since:2017-03-29 until:2017-03-30', 'Paypal -filter:retweets -filter:replies since:2017-03-30 until:2017-03-31', 'Paypal -filter:retweets -filter:replies since:2017-03-31 until:2017-04-01', 'Paypal -filter:retweets -filter:replies since:2017-04-01 until:2017-04-02']
# INFO: Got 176 tweets (176 new).
# INFO: Got 392 tweets (216 new).
# INFO: Got 680 tweets (288 new).
# INFO: Got 960 tweets (280 new).
# INFO: Got 1168 tweets (208 new).
# INFO: Got 1327 tweets (159 new).
# INFO: Got 1584 tweets (257 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-04-02 until:2017-04-03', 'Paypal -filter:retweets -filter:replies since:2017-04-03 until:2017-04-04', 'Paypal -filter:retweets -filter:replies since:2017-04-04 until:2017-04-05', 'Paypal -filter:retweets -filter:replies since:2017-04-05 until:2017-04-06', 'Paypal -filter:retweets -filter:replies since:2017-04-06 until:2017-04-07', 'Paypal -filter:retweets -filter:replies since:2017-04-07 until:2017-04-08', 'Paypal -filter:retweets -filter:replies since:2017-04-08 until:2017-04-09']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 137 tweets (18 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-04-09 until:2017-04-10', 'Paypal -filter:retweets -filter:replies since:2017-04-10 until:2017-04-11', 'Paypal -filter:retweets -filter:replies since:2017-04-11 until:2017-04-12', 'Paypal -filter:retweets -filter:replies since:2017-04-12 until:2017-04-13', 'Paypal -filter:retweets -filter:replies since:2017-04-13 until:2017-04-14', 'Paypal -filter:retweets -filter:replies since:2017-04-14 until:2017-04-15', 'Paypal -filter:retweets -filter:replies since:2017-04-15 until:2017-04-16']
# INFO: Got 13 tweets (13 new).
# INFO: Got 33 tweets (20 new).
# INFO: Got 52 tweets (19 new).
# INFO: Got 72 tweets (20 new).
# INFO: Got 92 tweets (20 new).
# INFO: Got 132 tweets (40 new).
# INFO: Got 172 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-04-16 until:2017-04-17', 'Paypal -filter:retweets -filter:replies since:2017-04-17 until:2017-04-18', 'Paypal -filter:retweets -filter:replies since:2017-04-18 until:2017-04-19', 'Paypal -filter:retweets -filter:replies since:2017-04-19 until:2017-04-20', 'Paypal -filter:retweets -filter:replies since:2017-04-20 until:2017-04-21', 'Paypal -filter:retweets -filter:replies since:2017-04-21 until:2017-04-22', 'Paypal -filter:retweets -filter:replies since:2017-04-22 until:2017-04-23']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 118 tweets (38 new).
# INFO: Got 158 tweets (40 new).
# INFO: Got 198 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-04-23 until:2017-04-24', 'Paypal -filter:retweets -filter:replies since:2017-04-24 until:2017-04-25', 'Paypal -filter:retweets -filter:replies since:2017-04-25 until:2017-04-26', 'Paypal -filter:retweets -filter:replies since:2017-04-26 until:2017-04-27', 'Paypal -filter:retweets -filter:replies since:2017-04-27 until:2017-04-28', 'Paypal -filter:retweets -filter:replies since:2017-04-28 until:2017-04-29', 'Paypal -filter:retweets -filter:replies since:2017-04-29 until:2017-04-30']
# INFO: Got 1901 tweets (1901 new).
# INFO: Got 4072 tweets (2171 new).
# INFO: Got 6077 tweets (2005 new).
# INFO: Got 8157 tweets (2080 new).
# INFO: Got 10164 tweets (2007 new).
# INFO: Got 12328 tweets (2164 new).
# INFO: Got 14341 tweets (2013 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-04-30 until:2017-05-01', 'Paypal -filter:retweets -filter:replies since:2017-05-01 until:2017-05-02', 'Paypal -filter:retweets -filter:replies since:2017-05-02 until:2017-05-03', 'Paypal -filter:retweets -filter:replies since:2017-05-03 until:2017-05-04', 'Paypal -filter:retweets -filter:replies since:2017-05-04 until:2017-05-05', 'Paypal -filter:retweets -filter:replies since:2017-05-05 until:2017-05-06', 'Paypal -filter:retweets -filter:replies since:2017-05-06 until:2017-05-07']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 119 tweets (19 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-05-07 until:2017-05-08', 'Paypal -filter:retweets -filter:replies since:2017-05-08 until:2017-05-09', 'Paypal -filter:retweets -filter:replies since:2017-05-09 until:2017-05-10', 'Paypal -filter:retweets -filter:replies since:2017-05-10 until:2017-05-11', 'Paypal -filter:retweets -filter:replies since:2017-05-11 until:2017-05-12', 'Paypal -filter:retweets -filter:replies since:2017-05-12 until:2017-05-13', 'Paypal -filter:retweets -filter:replies since:2017-05-13 until:2017-05-14']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 160 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-05-14 until:2017-05-15', 'Paypal -filter:retweets -filter:replies since:2017-05-15 until:2017-05-16', 'Paypal -filter:retweets -filter:replies since:2017-05-16 until:2017-05-17', 'Paypal -filter:retweets -filter:replies since:2017-05-17 until:2017-05-18', 'Paypal -filter:retweets -filter:replies since:2017-05-18 until:2017-05-19', 'Paypal -filter:retweets -filter:replies since:2017-05-19 until:2017-05-20', 'Paypal -filter:retweets -filter:replies since:2017-05-20 until:2017-05-21']
# INFO: Got 2450 tweets (2450 new).
# INFO: Got 5086 tweets (2636 new).
# INFO: Got 7549 tweets (2463 new).
# INFO: Got 9940 tweets (2391 new).
# INFO: Got 12545 tweets (2605 new).
# INFO: Got 15218 tweets (2673 new).
# INFO: Got 17878 tweets (2660 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-05-21 until:2017-05-22', 'Paypal -filter:retweets -filter:replies since:2017-05-22 until:2017-05-23', 'Paypal -filter:retweets -filter:replies since:2017-05-23 until:2017-05-24', 'Paypal -filter:retweets -filter:replies since:2017-05-24 until:2017-05-25', 'Paypal -filter:retweets -filter:replies since:2017-05-25 until:2017-05-26', 'Paypal -filter:retweets -filter:replies since:2017-05-26 until:2017-05-27', 'Paypal -filter:retweets -filter:replies since:2017-05-27 until:2017-05-28']
# INFO: Got 2046 tweets (2046 new).
# INFO: Got 4128 tweets (2082 new).
# INFO: Got 6118 tweets (1990 new).
# INFO: Got 7950 tweets (1832 new).
# INFO: Got 9957 tweets (2007 new).
# INFO: Got 12036 tweets (2079 new).
# INFO: Got 14022 tweets (1986 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-05-28 until:2017-05-29', 'Paypal -filter:retweets -filter:replies since:2017-05-29 until:2017-05-30', 'Paypal -filter:retweets -filter:replies since:2017-05-30 until:2017-05-31', 'Paypal -filter:retweets -filter:replies since:2017-05-31 until:2017-06-01', 'Paypal -filter:retweets -filter:replies since:2017-06-01 until:2017-06-02', 'Paypal -filter:retweets -filter:replies since:2017-06-02 until:2017-06-03', 'Paypal -filter:retweets -filter:replies since:2017-06-03 until:2017-06-04']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-06-04 until:2017-06-05', 'Paypal -filter:retweets -filter:replies since:2017-06-05 until:2017-06-06', 'Paypal -filter:retweets -filter:replies since:2017-06-06 until:2017-06-07', 'Paypal -filter:retweets -filter:replies since:2017-06-07 until:2017-06-08', 'Paypal -filter:retweets -filter:replies since:2017-06-08 until:2017-06-09', 'Paypal -filter:retweets -filter:replies since:2017-06-09 until:2017-06-10', 'Paypal -filter:retweets -filter:replies since:2017-06-10 until:2017-06-11']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-06-11 until:2017-06-12', 'Paypal -filter:retweets -filter:replies since:2017-06-12 until:2017-06-13', 'Paypal -filter:retweets -filter:replies since:2017-06-13 until:2017-06-14', 'Paypal -filter:retweets -filter:replies since:2017-06-14 until:2017-06-15', 'Paypal -filter:retweets -filter:replies since:2017-06-15 until:2017-06-16', 'Paypal -filter:retweets -filter:replies since:2017-06-16 until:2017-06-17', 'Paypal -filter:retweets -filter:replies since:2017-06-17 until:2017-06-18']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-06-18 until:2017-06-19', 'Paypal -filter:retweets -filter:replies since:2017-06-19 until:2017-06-20', 'Paypal -filter:retweets -filter:replies since:2017-06-20 until:2017-06-21', 'Paypal -filter:retweets -filter:replies since:2017-06-21 until:2017-06-22', 'Paypal -filter:retweets -filter:replies since:2017-06-22 until:2017-06-23', 'Paypal -filter:retweets -filter:replies since:2017-06-23 until:2017-06-24', 'Paypal -filter:retweets -filter:replies since:2017-06-24 until:2017-06-25']
# INFO: Got 19 tweets (19 new).
# INFO: Got 37 tweets (18 new).
# INFO: Got 57 tweets (20 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 137 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-06-25 until:2017-06-26', 'Paypal -filter:retweets -filter:replies since:2017-06-26 until:2017-06-27', 'Paypal -filter:retweets -filter:replies since:2017-06-27 until:2017-06-28', 'Paypal -filter:retweets -filter:replies since:2017-06-28 until:2017-06-29', 'Paypal -filter:retweets -filter:replies since:2017-06-29 until:2017-06-30', 'Paypal -filter:retweets -filter:replies since:2017-06-30 until:2017-07-01', 'Paypal -filter:retweets -filter:replies since:2017-07-01 until:2017-07-02']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 139 tweets (40 new).
# INFO: Got 199 tweets (60 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-07-02 until:2017-07-03', 'Paypal -filter:retweets -filter:replies since:2017-07-03 until:2017-07-04', 'Paypal -filter:retweets -filter:replies since:2017-07-04 until:2017-07-05', 'Paypal -filter:retweets -filter:replies since:2017-07-05 until:2017-07-06', 'Paypal -filter:retweets -filter:replies since:2017-07-06 until:2017-07-07', 'Paypal -filter:retweets -filter:replies since:2017-07-07 until:2017-07-08', 'Paypal -filter:retweets -filter:replies since:2017-07-08 until:2017-07-09']
# INFO: Got 2192 tweets (2192 new).
# INFO: Got 4175 tweets (1983 new).
# INFO: Got 6254 tweets (2079 new).
# INFO: Got 8258 tweets (2004 new).
# INFO: Got 10258 tweets (2000 new).
# INFO: Got 12330 tweets (2072 new).
# INFO: Got 14200 tweets (1870 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-07-09 until:2017-07-10', 'Paypal -filter:retweets -filter:replies since:2017-07-10 until:2017-07-11', 'Paypal -filter:retweets -filter:replies since:2017-07-11 until:2017-07-12', 'Paypal -filter:retweets -filter:replies since:2017-07-12 until:2017-07-13', 'Paypal -filter:retweets -filter:replies since:2017-07-13 until:2017-07-14', 'Paypal -filter:retweets -filter:replies since:2017-07-14 until:2017-07-15', 'Paypal -filter:retweets -filter:replies since:2017-07-15 until:2017-07-16']
# INFO: Got 2448 tweets (2448 new).
# INFO: Got 5168 tweets (2720 new).
# INFO: Got 8098 tweets (2930 new).
# INFO: Got 10814 tweets (2716 new).
# INFO: Got 13499 tweets (2685 new).
# INFO: Got 16254 tweets (2755 new).
# INFO: Got 18987 tweets (2733 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-07-16 until:2017-07-17', 'Paypal -filter:retweets -filter:replies since:2017-07-17 until:2017-07-18', 'Paypal -filter:retweets -filter:replies since:2017-07-18 until:2017-07-19', 'Paypal -filter:retweets -filter:replies since:2017-07-19 until:2017-07-20', 'Paypal -filter:retweets -filter:replies since:2017-07-20 until:2017-07-21', 'Paypal -filter:retweets -filter:replies since:2017-07-21 until:2017-07-22', 'Paypal -filter:retweets -filter:replies since:2017-07-22 until:2017-07-23']
# INFO: Got 1787 tweets (1787 new).
# INFO: Got 3544 tweets (1757 new).
# INFO: Got 5398 tweets (1854 new).
# INFO: Got 6934 tweets (1536 new).
# INFO: Got 8574 tweets (1640 new).
# INFO: Got 10246 tweets (1672 new).
# INFO: Got 12094 tweets (1848 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-07-23 until:2017-07-24', 'Paypal -filter:retweets -filter:replies since:2017-07-24 until:2017-07-25', 'Paypal -filter:retweets -filter:replies since:2017-07-25 until:2017-07-26', 'Paypal -filter:retweets -filter:replies since:2017-07-26 until:2017-07-27', 'Paypal -filter:retweets -filter:replies since:2017-07-27 until:2017-07-28', 'Paypal -filter:retweets -filter:replies since:2017-07-28 until:2017-07-29', 'Paypal -filter:retweets -filter:replies since:2017-07-29 until:2017-07-30']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 100 tweets (40 new).
# INFO: Got 140 tweets (40 new).
# INFO: Got 180 tweets (40 new).
# INFO: Got 218 tweets (38 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-07-30 until:2017-07-31', 'Paypal -filter:retweets -filter:replies since:2017-07-31 until:2017-08-01', 'Paypal -filter:retweets -filter:replies since:2017-08-01 until:2017-08-02', 'Paypal -filter:retweets -filter:replies since:2017-08-02 until:2017-08-03', 'Paypal -filter:retweets -filter:replies since:2017-08-03 until:2017-08-04', 'Paypal -filter:retweets -filter:replies since:2017-08-04 until:2017-08-05', 'Paypal -filter:retweets -filter:replies since:2017-08-05 until:2017-08-06']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-08-06 until:2017-08-07', 'Paypal -filter:retweets -filter:replies since:2017-08-07 until:2017-08-08', 'Paypal -filter:retweets -filter:replies since:2017-08-08 until:2017-08-09', 'Paypal -filter:retweets -filter:replies since:2017-08-09 until:2017-08-10', 'Paypal -filter:retweets -filter:replies since:2017-08-10 until:2017-08-11', 'Paypal -filter:retweets -filter:replies since:2017-08-11 until:2017-08-12', 'Paypal -filter:retweets -filter:replies since:2017-08-12 until:2017-08-13']
# INFO: Got 19 tweets (19 new).
# INFO: Got 31 tweets (12 new).
# INFO: Got 51 tweets (20 new).
# INFO: Got 71 tweets (20 new).
# INFO: Got 90 tweets (19 new).
# INFO: Got 110 tweets (20 new).
# INFO: Got 150 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-08-13 until:2017-08-14', 'Paypal -filter:retweets -filter:replies since:2017-08-14 until:2017-08-15', 'Paypal -filter:retweets -filter:replies since:2017-08-15 until:2017-08-16', 'Paypal -filter:retweets -filter:replies since:2017-08-16 until:2017-08-17', 'Paypal -filter:retweets -filter:replies since:2017-08-17 until:2017-08-18', 'Paypal -filter:retweets -filter:replies since:2017-08-18 until:2017-08-19', 'Paypal -filter:retweets -filter:replies since:2017-08-19 until:2017-08-20']
# INFO: Got 20 tweets (20 new).
# INFO: Got 37 tweets (17 new).
# INFO: Got 57 tweets (20 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 96 tweets (19 new).
# INFO: Got 116 tweets (20 new).
# INFO: Got 136 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-08-20 until:2017-08-21', 'Paypal -filter:retweets -filter:replies since:2017-08-21 until:2017-08-22', 'Paypal -filter:retweets -filter:replies since:2017-08-22 until:2017-08-23', 'Paypal -filter:retweets -filter:replies since:2017-08-23 until:2017-08-24', 'Paypal -filter:retweets -filter:replies since:2017-08-24 until:2017-08-25', 'Paypal -filter:retweets -filter:replies since:2017-08-25 until:2017-08-26', 'Paypal -filter:retweets -filter:replies since:2017-08-26 until:2017-08-27']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 98 tweets (19 new).
# INFO: Got 118 tweets (20 new).
# INFO: Got 138 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-08-27 until:2017-08-28', 'Paypal -filter:retweets -filter:replies since:2017-08-28 until:2017-08-29', 'Paypal -filter:retweets -filter:replies since:2017-08-29 until:2017-08-30', 'Paypal -filter:retweets -filter:replies since:2017-08-30 until:2017-08-31', 'Paypal -filter:retweets -filter:replies since:2017-08-31 until:2017-09-01', 'Paypal -filter:retweets -filter:replies since:2017-09-01 until:2017-09-02', 'Paypal -filter:retweets -filter:replies since:2017-09-02 until:2017-09-03']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 118 tweets (19 new).
# INFO: Got 138 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-09-03 until:2017-09-04', 'Paypal -filter:retweets -filter:replies since:2017-09-04 until:2017-09-05', 'Paypal -filter:retweets -filter:replies since:2017-09-05 until:2017-09-06', 'Paypal -filter:retweets -filter:replies since:2017-09-06 until:2017-09-07', 'Paypal -filter:retweets -filter:replies since:2017-09-07 until:2017-09-08', 'Paypal -filter:retweets -filter:replies since:2017-09-08 until:2017-09-09', 'Paypal -filter:retweets -filter:replies since:2017-09-09 until:2017-09-10']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-09-10 until:2017-09-11', 'Paypal -filter:retweets -filter:replies since:2017-09-11 until:2017-09-12', 'Paypal -filter:retweets -filter:replies since:2017-09-12 until:2017-09-13', 'Paypal -filter:retweets -filter:replies since:2017-09-13 until:2017-09-14', 'Paypal -filter:retweets -filter:replies since:2017-09-14 until:2017-09-15', 'Paypal -filter:retweets -filter:replies since:2017-09-15 until:2017-09-16', 'Paypal -filter:retweets -filter:replies since:2017-09-16 until:2017-09-17']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-09-17 until:2017-09-18', 'Paypal -filter:retweets -filter:replies since:2017-09-18 until:2017-09-19', 'Paypal -filter:retweets -filter:replies since:2017-09-19 until:2017-09-20', 'Paypal -filter:retweets -filter:replies since:2017-09-20 until:2017-09-21', 'Paypal -filter:retweets -filter:replies since:2017-09-21 until:2017-09-22', 'Paypal -filter:retweets -filter:replies since:2017-09-22 until:2017-09-23', 'Paypal -filter:retweets -filter:replies since:2017-09-23 until:2017-09-24']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-09-24 until:2017-09-25', 'Paypal -filter:retweets -filter:replies since:2017-09-25 until:2017-09-26', 'Paypal -filter:retweets -filter:replies since:2017-09-26 until:2017-09-27', 'Paypal -filter:retweets -filter:replies since:2017-09-27 until:2017-09-28', 'Paypal -filter:retweets -filter:replies since:2017-09-28 until:2017-09-29', 'Paypal -filter:retweets -filter:replies since:2017-09-29 until:2017-09-30', 'Paypal -filter:retweets -filter:replies since:2017-09-30 until:2017-10-01']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 119 tweets (19 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-10-01 until:2017-10-02', 'Paypal -filter:retweets -filter:replies since:2017-10-02 until:2017-10-03', 'Paypal -filter:retweets -filter:replies since:2017-10-03 until:2017-10-04', 'Paypal -filter:retweets -filter:replies since:2017-10-04 until:2017-10-05', 'Paypal -filter:retweets -filter:replies since:2017-10-05 until:2017-10-06', 'Paypal -filter:retweets -filter:replies since:2017-10-06 until:2017-10-07', 'Paypal -filter:retweets -filter:replies since:2017-10-07 until:2017-10-08']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 139 tweets (19 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-10-08 until:2017-10-09', 'Paypal -filter:retweets -filter:replies since:2017-10-09 until:2017-10-10', 'Paypal -filter:retweets -filter:replies since:2017-10-10 until:2017-10-11', 'Paypal -filter:retweets -filter:replies since:2017-10-11 until:2017-10-12', 'Paypal -filter:retweets -filter:replies since:2017-10-12 until:2017-10-13', 'Paypal -filter:retweets -filter:replies since:2017-10-13 until:2017-10-14', 'Paypal -filter:retweets -filter:replies since:2017-10-14 until:2017-10-15']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-10-15 until:2017-10-16', 'Paypal -filter:retweets -filter:replies since:2017-10-16 until:2017-10-17', 'Paypal -filter:retweets -filter:replies since:2017-10-17 until:2017-10-18', 'Paypal -filter:retweets -filter:replies since:2017-10-18 until:2017-10-19', 'Paypal -filter:retweets -filter:replies since:2017-10-19 until:2017-10-20', 'Paypal -filter:retweets -filter:replies since:2017-10-20 until:2017-10-21', 'Paypal -filter:retweets -filter:replies since:2017-10-21 until:2017-10-22']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-10-22 until:2017-10-23', 'Paypal -filter:retweets -filter:replies since:2017-10-23 until:2017-10-24', 'Paypal -filter:retweets -filter:replies since:2017-10-24 until:2017-10-25', 'Paypal -filter:retweets -filter:replies since:2017-10-25 until:2017-10-26', 'Paypal -filter:retweets -filter:replies since:2017-10-26 until:2017-10-27', 'Paypal -filter:retweets -filter:replies since:2017-10-27 until:2017-10-28', 'Paypal -filter:retweets -filter:replies since:2017-10-28 until:2017-10-29']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-10-29 until:2017-10-30', 'Paypal -filter:retweets -filter:replies since:2017-10-30 until:2017-10-31', 'Paypal -filter:retweets -filter:replies since:2017-10-31 until:2017-11-01', 'Paypal -filter:retweets -filter:replies since:2017-11-01 until:2017-11-02', 'Paypal -filter:retweets -filter:replies since:2017-11-02 until:2017-11-03', 'Paypal -filter:retweets -filter:replies since:2017-11-03 until:2017-11-04', 'Paypal -filter:retweets -filter:replies since:2017-11-04 until:2017-11-05']
# INFO: Got 2273 tweets (2273 new).
# INFO: Got 4859 tweets (2586 new).
# INFO: Got 7495 tweets (2636 new).
# INFO: Got 10055 tweets (2560 new).
# INFO: Got 12577 tweets (2522 new).
# INFO: Got 15122 tweets (2545 new).
# INFO: Got 17550 tweets (2428 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-11-05 until:2017-11-06', 'Paypal -filter:retweets -filter:replies since:2017-11-06 until:2017-11-07', 'Paypal -filter:retweets -filter:replies since:2017-11-07 until:2017-11-08', 'Paypal -filter:retweets -filter:replies since:2017-11-08 until:2017-11-09', 'Paypal -filter:retweets -filter:replies since:2017-11-09 until:2017-11-10', 'Paypal -filter:retweets -filter:replies since:2017-11-10 until:2017-11-11', 'Paypal -filter:retweets -filter:replies since:2017-11-11 until:2017-11-12']
# INFO: Got 1606 tweets (1606 new).
# INFO: Got 3074 tweets (1468 new).
# INFO: Got 4564 tweets (1490 new).
# INFO: Got 6161 tweets (1597 new).
# INFO: Got 7813 tweets (1652 new).
# INFO: Got 9268 tweets (1455 new).
# INFO: Got 10707 tweets (1439 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-11-12 until:2017-11-13', 'Paypal -filter:retweets -filter:replies since:2017-11-13 until:2017-11-14', 'Paypal -filter:retweets -filter:replies since:2017-11-14 until:2017-11-15', 'Paypal -filter:retweets -filter:replies since:2017-11-15 until:2017-11-16', 'Paypal -filter:retweets -filter:replies since:2017-11-16 until:2017-11-17', 'Paypal -filter:retweets -filter:replies since:2017-11-17 until:2017-11-18', 'Paypal -filter:retweets -filter:replies since:2017-11-18 until:2017-11-19']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 57 tweets (17 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 137 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-11-19 until:2017-11-20', 'Paypal -filter:retweets -filter:replies since:2017-11-20 until:2017-11-21', 'Paypal -filter:retweets -filter:replies since:2017-11-21 until:2017-11-22', 'Paypal -filter:retweets -filter:replies since:2017-11-22 until:2017-11-23', 'Paypal -filter:retweets -filter:replies since:2017-11-23 until:2017-11-24', 'Paypal -filter:retweets -filter:replies since:2017-11-24 until:2017-11-25', 'Paypal -filter:retweets -filter:replies since:2017-11-25 until:2017-11-26']
# INFO: Got 20 tweets (20 new).
# INFO: Got 38 tweets (18 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 78 tweets (20 new).
# INFO: Got 98 tweets (20 new).
# INFO: Got 118 tweets (20 new).
# INFO: Got 138 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-11-26 until:2017-11-27', 'Paypal -filter:retweets -filter:replies since:2017-11-27 until:2017-11-28', 'Paypal -filter:retweets -filter:replies since:2017-11-28 until:2017-11-29', 'Paypal -filter:retweets -filter:replies since:2017-11-29 until:2017-11-30', 'Paypal -filter:retweets -filter:replies since:2017-11-30 until:2017-12-01', 'Paypal -filter:retweets -filter:replies since:2017-12-01 until:2017-12-02', 'Paypal -filter:retweets -filter:replies since:2017-12-02 until:2017-12-03']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 159 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-12-03 until:2017-12-04', 'Paypal -filter:retweets -filter:replies since:2017-12-04 until:2017-12-05', 'Paypal -filter:retweets -filter:replies since:2017-12-05 until:2017-12-06', 'Paypal -filter:retweets -filter:replies since:2017-12-06 until:2017-12-07', 'Paypal -filter:retweets -filter:replies since:2017-12-07 until:2017-12-08', 'Paypal -filter:retweets -filter:replies since:2017-12-08 until:2017-12-09', 'Paypal -filter:retweets -filter:replies since:2017-12-09 until:2017-12-10']
# INFO: Got 19 tweets (19 new).
# INFO: Got 38 tweets (19 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 77 tweets (19 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 136 tweets (19 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-12-10 until:2017-12-11', 'Paypal -filter:retweets -filter:replies since:2017-12-11 until:2017-12-12', 'Paypal -filter:retweets -filter:replies since:2017-12-12 until:2017-12-13', 'Paypal -filter:retweets -filter:replies since:2017-12-13 until:2017-12-14', 'Paypal -filter:retweets -filter:replies since:2017-12-14 until:2017-12-15', 'Paypal -filter:retweets -filter:replies since:2017-12-15 until:2017-12-16', 'Paypal -filter:retweets -filter:replies since:2017-12-16 until:2017-12-17']
# INFO: Got 20 tweets (20 new).
# INFO: Got 38 tweets (18 new).
# INFO: Got 57 tweets (19 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 116 tweets (19 new).
# INFO: Got 156 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-12-17 until:2017-12-18', 'Paypal -filter:retweets -filter:replies since:2017-12-18 until:2017-12-19', 'Paypal -filter:retweets -filter:replies since:2017-12-19 until:2017-12-20', 'Paypal -filter:retweets -filter:replies since:2017-12-20 until:2017-12-21', 'Paypal -filter:retweets -filter:replies since:2017-12-21 until:2017-12-22', 'Paypal -filter:retweets -filter:replies since:2017-12-22 until:2017-12-23', 'Paypal -filter:retweets -filter:replies since:2017-12-23 until:2017-12-24']
# INFO: Got 19 tweets (19 new).
# INFO: Got 37 tweets (18 new).
# INFO: Got 57 tweets (20 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 137 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-12-24 until:2017-12-25', 'Paypal -filter:retweets -filter:replies since:2017-12-25 until:2017-12-26', 'Paypal -filter:retweets -filter:replies since:2017-12-26 until:2017-12-27', 'Paypal -filter:retweets -filter:replies since:2017-12-27 until:2017-12-28', 'Paypal -filter:retweets -filter:replies since:2017-12-28 until:2017-12-29', 'Paypal -filter:retweets -filter:replies since:2017-12-29 until:2017-12-30', 'Paypal -filter:retweets -filter:replies since:2017-12-30 until:2017-12-31']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 98 tweets (19 new).
# INFO: Got 117 tweets (19 new).
# INFO: Got 137 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2017-12-31 until:2018-01-01', 'Paypal -filter:retweets -filter:replies since:2018-01-01 until:2018-01-02', 'Paypal -filter:retweets -filter:replies since:2018-01-02 until:2018-01-03', 'Paypal -filter:retweets -filter:replies since:2018-01-03 until:2018-01-04', 'Paypal -filter:retweets -filter:replies since:2018-01-04 until:2018-01-05', 'Paypal -filter:retweets -filter:replies since:2018-01-05 until:2018-01-06', 'Paypal -filter:retweets -filter:replies since:2018-01-06 until:2018-01-07']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 139 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-01-07 until:2018-01-08', 'Paypal -filter:retweets -filter:replies since:2018-01-08 until:2018-01-09', 'Paypal -filter:retweets -filter:replies since:2018-01-09 until:2018-01-10', 'Paypal -filter:retweets -filter:replies since:2018-01-10 until:2018-01-11', 'Paypal -filter:retweets -filter:replies since:2018-01-11 until:2018-01-12', 'Paypal -filter:retweets -filter:replies since:2018-01-12 until:2018-01-13', 'Paypal -filter:retweets -filter:replies since:2018-01-13 until:2018-01-14']
# INFO: Got 19 tweets (19 new).
# INFO: Got 37 tweets (18 new).
# INFO: Got 57 tweets (20 new).
# INFO: Got 76 tweets (19 new).
# INFO: Got 92 tweets (16 new).
# INFO: Got 110 tweets (18 new).
# INFO: Got 130 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-01-14 until:2018-01-15', 'Paypal -filter:retweets -filter:replies since:2018-01-15 until:2018-01-16', 'Paypal -filter:retweets -filter:replies since:2018-01-16 until:2018-01-17', 'Paypal -filter:retweets -filter:replies since:2018-01-17 until:2018-01-18', 'Paypal -filter:retweets -filter:replies since:2018-01-18 until:2018-01-19', 'Paypal -filter:retweets -filter:replies since:2018-01-19 until:2018-01-20', 'Paypal -filter:retweets -filter:replies since:2018-01-20 until:2018-01-21']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 96 tweets (17 new).
# INFO: Got 116 tweets (20 new).
# INFO: Got 136 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-01-21 until:2018-01-22', 'Paypal -filter:retweets -filter:replies since:2018-01-22 until:2018-01-23', 'Paypal -filter:retweets -filter:replies since:2018-01-23 until:2018-01-24', 'Paypal -filter:retweets -filter:replies since:2018-01-24 until:2018-01-25', 'Paypal -filter:retweets -filter:replies since:2018-01-25 until:2018-01-26', 'Paypal -filter:retweets -filter:replies since:2018-01-26 until:2018-01-27', 'Paypal -filter:retweets -filter:replies since:2018-01-27 until:2018-01-28']
# INFO: Got 18 tweets (18 new).
# INFO: Got 38 tweets (20 new).
# INFO: Got 54 tweets (16 new).
# INFO: Got 74 tweets (20 new).
# INFO: Got 94 tweets (20 new).
# INFO: Got 114 tweets (20 new).
# INFO: Got 134 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-01-28 until:2018-01-29', 'Paypal -filter:retweets -filter:replies since:2018-01-29 until:2018-01-30', 'Paypal -filter:retweets -filter:replies since:2018-01-30 until:2018-01-31', 'Paypal -filter:retweets -filter:replies since:2018-01-31 until:2018-02-01', 'Paypal -filter:retweets -filter:replies since:2018-02-01 until:2018-02-02', 'Paypal -filter:retweets -filter:replies since:2018-02-02 until:2018-02-03', 'Paypal -filter:retweets -filter:replies since:2018-02-03 until:2018-02-04']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-02-04 until:2018-02-05', 'Paypal -filter:retweets -filter:replies since:2018-02-05 until:2018-02-06', 'Paypal -filter:retweets -filter:replies since:2018-02-06 until:2018-02-07', 'Paypal -filter:retweets -filter:replies since:2018-02-07 until:2018-02-08', 'Paypal -filter:retweets -filter:replies since:2018-02-08 until:2018-02-09', 'Paypal -filter:retweets -filter:replies since:2018-02-09 until:2018-02-10', 'Paypal -filter:retweets -filter:replies since:2018-02-10 until:2018-02-11']
# INFO: Got 19 tweets (19 new).
# INFO: Got 38 tweets (19 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 92 tweets (34 new).
# INFO: Got 132 tweets (40 new).
# INFO: Got 190 tweets (58 new).
# INFO: Got 265 tweets (75 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-02-11 until:2018-02-12', 'Paypal -filter:retweets -filter:replies since:2018-02-12 until:2018-02-13', 'Paypal -filter:retweets -filter:replies since:2018-02-13 until:2018-02-14', 'Paypal -filter:retweets -filter:replies since:2018-02-14 until:2018-02-15', 'Paypal -filter:retweets -filter:replies since:2018-02-15 until:2018-02-16', 'Paypal -filter:retweets -filter:replies since:2018-02-16 until:2018-02-17', 'Paypal -filter:retweets -filter:replies since:2018-02-17 until:2018-02-18']
# INFO: Got 2232 tweets (2232 new).
# INFO: Got 4906 tweets (2674 new).
# INFO: Got 7460 tweets (2554 new).
# INFO: Got 10118 tweets (2658 new).
# INFO: Got 13002 tweets (2884 new).
# INFO: Got 15863 tweets (2861 new).
# INFO: Got 18770 tweets (2907 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-02-18 until:2018-02-19', 'Paypal -filter:retweets -filter:replies since:2018-02-19 until:2018-02-20', 'Paypal -filter:retweets -filter:replies since:2018-02-20 until:2018-02-21', 'Paypal -filter:retweets -filter:replies since:2018-02-21 until:2018-02-22', 'Paypal -filter:retweets -filter:replies since:2018-02-22 until:2018-02-23', 'Paypal -filter:retweets -filter:replies since:2018-02-23 until:2018-02-24', 'Paypal -filter:retweets -filter:replies since:2018-02-24 until:2018-02-25']
# INFO: Got 2085 tweets (2085 new).
# INFO: Got 4124 tweets (2039 new).
# INFO: Got 6446 tweets (2322 new).
# INFO: Got 8565 tweets (2119 new).
# INFO: Got 10789 tweets (2224 new).
# INFO: Got 12900 tweets (2111 new).
# INFO: Got 15284 tweets (2384 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-02-25 until:2018-02-26', 'Paypal -filter:retweets -filter:replies since:2018-02-26 until:2018-02-27', 'Paypal -filter:retweets -filter:replies since:2018-02-27 until:2018-02-28', 'Paypal -filter:retweets -filter:replies since:2018-02-28 until:2018-03-01', 'Paypal -filter:retweets -filter:replies since:2018-03-01 until:2018-03-02', 'Paypal -filter:retweets -filter:replies since:2018-03-02 until:2018-03-03', 'Paypal -filter:retweets -filter:replies since:2018-03-03 until:2018-03-04']
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 78 tweets (19 new).
# INFO: Got 98 tweets (20 new).
# INFO: Got 118 tweets (20 new).
# INFO: Got 138 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2018-03-04 until:2018-03-05', 'Paypal -filter:retweets -filter:replies since:2018-03-05 until:2018-03-06', 'Paypal -filter:retweets -filter:replies since:2018-03-06 until:2018-03-07', 'Paypal -filter:retweets -filter:replies since:2018-03-07 until:2018-03-08', 'Paypal -filter:retweets -filter:replies since:2018-03-08 until:2018-03-09', 'Paypal -filter:retweets -filter:replies since:2018-03-09 until:2018-03-10', 'Paypal -filter:retweets -filter:replies since:2018-03-10 until:2018-03-11']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 119 tweets (20 new).
# INFO: Got 138 tweets (19 new).
# ...
# INFO: Got 167 tweets (53 new).
# INFO: Got 219 tweets (52 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-11-10 until:2019-11-11', 'Paypal -filter:retweets -filter:replies since:2019-11-11 until:2019-11-12', 'Paypal -filter:retweets -filter:replies since:2019-11-12 until:2019-11-13', 'Paypal -filter:retweets -filter:replies since:2019-11-13 until:2019-11-14', 'Paypal -filter:retweets -filter:replies since:2019-11-14 until:2019-11-15', 'Paypal -filter:retweets -filter:replies since:2019-11-15 until:2019-11-16', 'Paypal -filter:retweets -filter:replies since:2019-11-16 until:2019-11-17']
# INFO: Got 1814 tweets (1814 new).
# INFO: Got 3893 tweets (2079 new).
# INFO: Got 5928 tweets (2035 new).
# INFO: Got 8071 tweets (2143 new).
# INFO: Got 10011 tweets (1940 new).
# INFO: Got 11823 tweets (1812 new).
# INFO: Got 13805 tweets (1982 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-11-17 until:2019-11-18', 'Paypal -filter:retweets -filter:replies since:2019-11-18 until:2019-11-19', 'Paypal -filter:retweets -filter:replies since:2019-11-19 until:2019-11-20', 'Paypal -filter:retweets -filter:replies since:2019-11-20 until:2019-11-21', 'Paypal -filter:retweets -filter:replies since:2019-11-21 until:2019-11-22', 'Paypal -filter:retweets -filter:replies since:2019-11-22 until:2019-11-23', 'Paypal -filter:retweets -filter:replies since:2019-11-23 until:2019-11-24']
# INFO: Got 19 tweets (19 new).
# INFO: Got 38 tweets (19 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 76 tweets (18 new).
# INFO: Got 114 tweets (38 new).
# INFO: Got 134 tweets (20 new).
# INFO: Got 190 tweets (56 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-11-24 until:2019-11-25', 'Paypal -filter:retweets -filter:replies since:2019-11-25 until:2019-11-26', 'Paypal -filter:retweets -filter:replies since:2019-11-26 until:2019-11-27', 'Paypal -filter:retweets -filter:replies since:2019-11-27 until:2019-11-28', 'Paypal -filter:retweets -filter:replies since:2019-11-28 until:2019-11-29', 'Paypal -filter:retweets -filter:replies since:2019-11-29 until:2019-11-30', 'Paypal -filter:retweets -filter:replies since:2019-11-30 until:2019-12-01']
# INFO: Got 1653 tweets (1653 new).
# INFO: Got 3574 tweets (1921 new).
# INFO: Got 5629 tweets (2055 new).
# INFO: Got 7764 tweets (2135 new).
# INFO: Got 9626 tweets (1862 new).
# INFO: Got 11743 tweets (2117 new).
# INFO: Got 13649 tweets (1906 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-12-01 until:2019-12-02', 'Paypal -filter:retweets -filter:replies since:2019-12-02 until:2019-12-03', 'Paypal -filter:retweets -filter:replies since:2019-12-03 until:2019-12-04', 'Paypal -filter:retweets -filter:replies since:2019-12-04 until:2019-12-05', 'Paypal -filter:retweets -filter:replies since:2019-12-05 until:2019-12-06', 'Paypal -filter:retweets -filter:replies since:2019-12-06 until:2019-12-07', 'Paypal -filter:retweets -filter:replies since:2019-12-07 until:2019-12-08']
# INFO: Got 2132 tweets (2132 new).
# INFO: Got 4559 tweets (2427 new).
# INFO: Got 7094 tweets (2535 new).
# INFO: Got 9642 tweets (2548 new).
# INFO: Got 12179 tweets (2537 new).
# INFO: Got 14610 tweets (2431 new).
# INFO: Got 17025 tweets (2415 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-12-08 until:2019-12-09', 'Paypal -filter:retweets -filter:replies since:2019-12-09 until:2019-12-10', 'Paypal -filter:retweets -filter:replies since:2019-12-10 until:2019-12-11', 'Paypal -filter:retweets -filter:replies since:2019-12-11 until:2019-12-12', 'Paypal -filter:retweets -filter:replies since:2019-12-12 until:2019-12-13', 'Paypal -filter:retweets -filter:replies since:2019-12-13 until:2019-12-14', 'Paypal -filter:retweets -filter:replies since:2019-12-14 until:2019-12-15']
# INFO: Got 1319 tweets (1319 new).
# INFO: Got 2640 tweets (1321 new).
# INFO: Got 4115 tweets (1475 new).
# INFO: Got 5480 tweets (1365 new).
# INFO: Got 6922 tweets (1442 new).
# INFO: Got 8329 tweets (1407 new).
# INFO: Got 9918 tweets (1589 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-12-15 until:2019-12-16', 'Paypal -filter:retweets -filter:replies since:2019-12-16 until:2019-12-17', 'Paypal -filter:retweets -filter:replies since:2019-12-17 until:2019-12-18', 'Paypal -filter:retweets -filter:replies since:2019-12-18 until:2019-12-19', 'Paypal -filter:retweets -filter:replies since:2019-12-19 until:2019-12-20', 'Paypal -filter:retweets -filter:replies since:2019-12-20 until:2019-12-21', 'Paypal -filter:retweets -filter:replies since:2019-12-21 until:2019-12-22']
# INFO: Got 19 tweets (19 new).
# INFO: Got 38 tweets (19 new).
# INFO: Got 53 tweets (15 new).
# INFO: Got 72 tweets (19 new).
# INFO: Got 112 tweets (40 new).
# INFO: Got 148 tweets (36 new).
# INFO: Got 188 tweets (40 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-12-22 until:2019-12-23', 'Paypal -filter:retweets -filter:replies since:2019-12-23 until:2019-12-24', 'Paypal -filter:retweets -filter:replies since:2019-12-24 until:2019-12-25', 'Paypal -filter:retweets -filter:replies since:2019-12-25 until:2019-12-26', 'Paypal -filter:retweets -filter:replies since:2019-12-26 until:2019-12-27', 'Paypal -filter:retweets -filter:replies since:2019-12-27 until:2019-12-28', 'Paypal -filter:retweets -filter:replies since:2019-12-28 until:2019-12-29']
# INFO: Got 1972 tweets (1972 new).
# INFO: Got 3833 tweets (1861 new).
# INFO: Got 6011 tweets (2178 new).
# INFO: Got 7954 tweets (1943 new).
# INFO: Got 9915 tweets (1961 new).
# INFO: Got 11849 tweets (1934 new).
# INFO: Got 13738 tweets (1889 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2019-12-29 until:2019-12-30', 'Paypal -filter:retweets -filter:replies since:2019-12-30 until:2019-12-31', 'Paypal -filter:retweets -filter:replies since:2019-12-31 until:2020-01-01', 'Paypal -filter:retweets -filter:replies since:2020-01-01 until:2020-01-02', 'Paypal -filter:retweets -filter:replies since:2020-01-02 until:2020-01-03', 'Paypal -filter:retweets -filter:replies since:2020-01-03 until:2020-01-04', 'Paypal -filter:retweets -filter:replies since:2020-01-04 until:2020-01-05']
# INFO: Got 19 tweets (19 new).
# INFO: Got 36 tweets (17 new).
# INFO: Got 53 tweets (17 new).
# INFO: Got 73 tweets (20 new).
# INFO: Got 91 tweets (18 new).
# INFO: Got 111 tweets (20 new).
# INFO: Got 131 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-01-05 until:2020-01-06', 'Paypal -filter:retweets -filter:replies since:2020-01-06 until:2020-01-07', 'Paypal -filter:retweets -filter:replies since:2020-01-07 until:2020-01-08', 'Paypal -filter:retweets -filter:replies since:2020-01-08 until:2020-01-09', 'Paypal -filter:retweets -filter:replies since:2020-01-09 until:2020-01-10', 'Paypal -filter:retweets -filter:replies since:2020-01-10 until:2020-01-11', 'Paypal -filter:retweets -filter:replies since:2020-01-11 until:2020-01-12']
# INFO: Got 17 tweets (17 new).
# INFO: Got 36 tweets (19 new).
# INFO: Got 52 tweets (16 new).
# INFO: Got 71 tweets (19 new).
# INFO: Got 109 tweets (38 new).
# INFO: Got 149 tweets (40 new).
# INFO: Got 195 tweets (46 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-01-12 until:2020-01-13', 'Paypal -filter:retweets -filter:replies since:2020-01-13 until:2020-01-14', 'Paypal -filter:retweets -filter:replies since:2020-01-14 until:2020-01-15', 'Paypal -filter:retweets -filter:replies since:2020-01-15 until:2020-01-16', 'Paypal -filter:retweets -filter:replies since:2020-01-16 until:2020-01-17', 'Paypal -filter:retweets -filter:replies since:2020-01-17 until:2020-01-18', 'Paypal -filter:retweets -filter:replies since:2020-01-18 until:2020-01-19']
# INFO: Got 2409 tweets (2409 new).
# INFO: Got 4784 tweets (2375 new).
# INFO: Got 7612 tweets (2828 new).
# INFO: Got 10260 tweets (2648 new).
# INFO: Got 12985 tweets (2725 new).
# INFO: Got 15630 tweets (2645 new).
# INFO: Got 18399 tweets (2769 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-01-19 until:2020-01-20', 'Paypal -filter:retweets -filter:replies since:2020-01-20 until:2020-01-21', 'Paypal -filter:retweets -filter:replies since:2020-01-21 until:2020-01-22', 'Paypal -filter:retweets -filter:replies since:2020-01-22 until:2020-01-23', 'Paypal -filter:retweets -filter:replies since:2020-01-23 until:2020-01-24', 'Paypal -filter:retweets -filter:replies since:2020-01-24 until:2020-01-25', 'Paypal -filter:retweets -filter:replies since:2020-01-25 until:2020-01-26']
# INFO: Got 2183 tweets (2183 new).
# INFO: Got 4453 tweets (2270 new).
# INFO: Got 7061 tweets (2608 new).
# INFO: Got 9660 tweets (2599 new).
# INFO: Got 12040 tweets (2380 new).
# INFO: Got 14645 tweets (2605 new).
# INFO: Got 17234 tweets (2589 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-01-26 until:2020-01-27', 'Paypal -filter:retweets -filter:replies since:2020-01-27 until:2020-01-28', 'Paypal -filter:retweets -filter:replies since:2020-01-28 until:2020-01-29', 'Paypal -filter:retweets -filter:replies since:2020-01-29 until:2020-01-30', 'Paypal -filter:retweets -filter:replies since:2020-01-30 until:2020-01-31', 'Paypal -filter:retweets -filter:replies since:2020-01-31 until:2020-02-01', 'Paypal -filter:retweets -filter:replies since:2020-02-01 until:2020-02-02']
# INFO: Got 559 tweets (559 new).
# INFO: Got 1023 tweets (464 new).
# INFO: Got 1524 tweets (501 new).
# INFO: Got 2022 tweets (498 new).
# INFO: Got 2484 tweets (462 new).
# INFO: Got 3008 tweets (524 new).
# INFO: Got 3527 tweets (519 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-02-02 until:2020-02-03', 'Paypal -filter:retweets -filter:replies since:2020-02-03 until:2020-02-04', 'Paypal -filter:retweets -filter:replies since:2020-02-04 until:2020-02-05', 'Paypal -filter:retweets -filter:replies since:2020-02-05 until:2020-02-06', 'Paypal -filter:retweets -filter:replies since:2020-02-06 until:2020-02-07', 'Paypal -filter:retweets -filter:replies since:2020-02-07 until:2020-02-08', 'Paypal -filter:retweets -filter:replies since:2020-02-08 until:2020-02-09']
# INFO: Got 18 tweets (18 new).
# INFO: Got 37 tweets (19 new).
# INFO: Got 50 tweets (13 new).
# INFO: Got 66 tweets (16 new).
# INFO: Got 86 tweets (20 new).
# INFO: Got 106 tweets (20 new).
# INFO: Got 125 tweets (19 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-02-09 until:2020-02-10', 'Paypal -filter:retweets -filter:replies since:2020-02-10 until:2020-02-11', 'Paypal -filter:retweets -filter:replies since:2020-02-11 until:2020-02-12', 'Paypal -filter:retweets -filter:replies since:2020-02-12 until:2020-02-13', 'Paypal -filter:retweets -filter:replies since:2020-02-13 until:2020-02-14', 'Paypal -filter:retweets -filter:replies since:2020-02-14 until:2020-02-15', 'Paypal -filter:retweets -filter:replies since:2020-02-15 until:2020-02-16']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 78 tweets (19 new).
# INFO: Got 96 tweets (18 new).
# INFO: Got 115 tweets (19 new).
# INFO: Got 133 tweets (18 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-02-16 until:2020-02-17', 'Paypal -filter:retweets -filter:replies since:2020-02-17 until:2020-02-18', 'Paypal -filter:retweets -filter:replies since:2020-02-18 until:2020-02-19', 'Paypal -filter:retweets -filter:replies since:2020-02-19 until:2020-02-20', 'Paypal -filter:retweets -filter:replies since:2020-02-20 until:2020-02-21', 'Paypal -filter:retweets -filter:replies since:2020-02-21 until:2020-02-22', 'Paypal -filter:retweets -filter:replies since:2020-02-22 until:2020-02-23']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 57 tweets (17 new).
# INFO: Got 77 tweets (20 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 137 tweets (20 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-02-23 until:2020-02-24', 'Paypal -filter:retweets -filter:replies since:2020-02-24 until:2020-02-25', 'Paypal -filter:retweets -filter:replies since:2020-02-25 until:2020-02-26', 'Paypal -filter:retweets -filter:replies since:2020-02-26 until:2020-02-27', 'Paypal -filter:retweets -filter:replies since:2020-02-27 until:2020-02-28', 'Paypal -filter:retweets -filter:replies since:2020-02-28 until:2020-02-29', 'Paypal -filter:retweets -filter:replies since:2020-02-29 until:2020-03-01']
# INFO: Got 10 tweets (10 new).
# INFO: Got 29 tweets (19 new).
# INFO: Got 45 tweets (16 new).
# INFO: Got 63 tweets (18 new).
# INFO: Got 83 tweets (20 new).
# INFO: Got 100 tweets (17 new).
# INFO: Got 119 tweets (19 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-03-01 until:2020-03-02', 'Paypal -filter:retweets -filter:replies since:2020-03-02 until:2020-03-03', 'Paypal -filter:retweets -filter:replies since:2020-03-03 until:2020-03-04', 'Paypal -filter:retweets -filter:replies since:2020-03-04 until:2020-03-05', 'Paypal -filter:retweets -filter:replies since:2020-03-05 until:2020-03-06', 'Paypal -filter:retweets -filter:replies since:2020-03-06 until:2020-03-07', 'Paypal -filter:retweets -filter:replies since:2020-03-07 until:2020-03-08']
# INFO: Got 19 tweets (19 new).
# INFO: Got 36 tweets (17 new).
# INFO: Got 54 tweets (18 new).
# INFO: Got 74 tweets (20 new).
# INFO: Got 94 tweets (20 new).
# INFO: Got 114 tweets (20 new).
# INFO: Got 133 tweets (19 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-03-08 until:2020-03-09', 'Paypal -filter:retweets -filter:replies since:2020-03-09 until:2020-03-10', 'Paypal -filter:retweets -filter:replies since:2020-03-10 until:2020-03-11', 'Paypal -filter:retweets -filter:replies since:2020-03-11 until:2020-03-12', 'Paypal -filter:retweets -filter:replies since:2020-03-12 until:2020-03-13', 'Paypal -filter:retweets -filter:replies since:2020-03-13 until:2020-03-14', 'Paypal -filter:retweets -filter:replies since:2020-03-14 until:2020-03-15']
# INFO: Got 20 tweets (20 new).
# INFO: Got 39 tweets (19 new).
# INFO: Got 59 tweets (20 new).
# INFO: Got 75 tweets (16 new).
# INFO: Got 95 tweets (20 new).
# INFO: Got 115 tweets (20 new).
# INFO: Got 149 tweets (34 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-03-15 until:2020-03-16', 'Paypal -filter:retweets -filter:replies since:2020-03-16 until:2020-03-17', 'Paypal -filter:retweets -filter:replies since:2020-03-17 until:2020-03-18', 'Paypal -filter:retweets -filter:replies since:2020-03-18 until:2020-03-19', 'Paypal -filter:retweets -filter:replies since:2020-03-19 until:2020-03-20', 'Paypal -filter:retweets -filter:replies since:2020-03-20 until:2020-03-21', 'Paypal -filter:retweets -filter:replies since:2020-03-21 until:2020-03-22']
# INFO: Got 19 tweets (19 new).
# INFO: Got 53 tweets (34 new).
# INFO: Got 93 tweets (40 new).
# INFO: Got 133 tweets (40 new).
# INFO: Got 193 tweets (60 new).
# INFO: Got 227 tweets (34 new).
# INFO: Got 281 tweets (54 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-03-22 until:2020-03-23', 'Paypal -filter:retweets -filter:replies since:2020-03-23 until:2020-03-24', 'Paypal -filter:retweets -filter:replies since:2020-03-24 until:2020-03-25', 'Paypal -filter:retweets -filter:replies since:2020-03-25 until:2020-03-26', 'Paypal -filter:retweets -filter:replies since:2020-03-26 until:2020-03-27', 'Paypal -filter:retweets -filter:replies since:2020-03-27 until:2020-03-28', 'Paypal -filter:retweets -filter:replies since:2020-03-28 until:2020-03-29']
# INFO: Got 12 tweets (12 new).
# INFO: Got 32 tweets (20 new).
# INFO: Got 48 tweets (16 new).
# INFO: Got 67 tweets (19 new).
# INFO: Got 124 tweets (57 new).
# INFO: Got 164 tweets (40 new).
# INFO: Got 224 tweets (60 new).
# INFO: queries: ['Paypal -filter:retweets -filter:replies since:2020-03-29 until:2020-03-30', 'Paypal -filter:retweets -filter:replies since:2020-03-30 until:2020-03-31', 'Paypal -filter:retweets -filter:replies since:2020-03-31 until:2020-04-01']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 57 tweets (18 new).
# Elapsed time: 17091.44544315338

# %% [markdown]
# # Clean Twitter Data
#
# - REMOVE SPECIAL CHARACTERS
# - REMOVE URL
# - REMOVE STOPWORDS
# - NORMALIZE WORDS: lower case, verbs, numbers to letter

# %%
if __name__ == '__main__':
    start = time.time()
    print(time.strftime("%I:%M:%S"))

    companies = ['Nvidia']
    for comp in companies:
        #define fields that will be read
        #comp = 'Oracle' #Adobe
        timeframe = '_20170101_20200401' #_20170101_20200401
        fields = ['timestamp','img_urls','links','replies','retweets','text','tweet_id']
        types = {'timestamp':'str','img_urls':'str','links':'str','replies':'str','retweets':'str','text':'str','tweet_id': 'str'}
        ''' tweets : data with only datetime and tweet text columns '''
        tweets = pd.read_csv(comp + timeframe + '.csv', sep = "|", header=0,usecols=fields,skip_blank_lines=True, dtype=types) #, index_col='tweet_id'
        tweets = tweets[fields]
        
        ''' tweets_clean: new dataframe that will store cleaned tweets '''
        # tweets_clean = pd.DataFrame(columns=['Date','Tweets',])
        ''' loop to clean text data 
            remove_characters removes special characters and url
            remove_stopwords removes stopwords '''
        if tweets.size != 0:
            tweets['comp'] = comp
            #args = [tuple(x) for x in tweets.to_numpy()]
            args = tweets.to_records(index=False)
            #multiprocessing for the normalisation and analysis
            pool_nb = min(5*os.cpu_count(),len(args))
            print('Using a pool of ' + str(pool_nb) + ' Processes')
            multiprocessing.freeze_support()
            with multiprocessing.Pool(processes=pool_nb) as pool:
                results = pool.starmap(project_lib.multiprocess_execution, args.tolist())
            print('Multiprocessing execution terminated')

        # Convert to dataframe and remove duplicates
        data_cleaned_with_sent = pd.DataFrame.from_records(results)
        data_cleaned_with_sent = data_cleaned_with_sent.drop_duplicates()
        ''' save clean data to csv '''
        print('Saving data to csv file ' + comp + '_Clean' + timeframe + '.csv')
        data_cleaned_with_sent.to_csv(comp + '_Clean' + timeframe + '.csv',sep='|', header=True, index=True)

    elapsed = time.time() - start
    print(f"Elapsed time: {elapsed}")
# Out:
# 08:13:09
# Using a pool of 60 Processes
# Multiprocessing execution terminated
# Saving data to csv file Nvidia_Clean_20170101_20200401.csv
# Elapsed time: 1767.8058140277863

# %% [markdown]
# # Create files with aggregated sentiments

# %%
companies = ['Microsoft', 'Apple', 'Mastercard','Intel Corp', 
             'Cisco Systems', 'Adobe', 'Nvidia',
             'Salesforce', 'PayPal', 'Oracle']
timeframe = '_20170101_20200401' #_20170101_20200401

for comp in companies:

    fields = ['timestamp','replies','retweets','Comp','Positive','Neutral','Negative']
    types = {'timestamp':'object','replies':'float64','retweets':'float64','Comp':'float64','Positive': 'float64','Neutral': 'float64','Negative': 'float64'}
    sentiments = pd.read_csv(comp + '_Clean' + timeframe + '.csv', sep = "|", header=0,usecols=fields,skip_blank_lines=True,dtype=types)#,dtype=types

    headers_sentiments = ['Comp','Positive','Negative']#,'CompWithRepRet'

    sentiments['Date']=pd.to_datetime(sentiments.timestamp).dt.date

    # Retrieve all sentiments
    sentiment_full = sentiments.groupby('Date').mean()

    sentiment_full.to_csv(comp + '_daily_sentiment_tweets.csv',sep='|', header=True, index=True, columns=headers_sentiments)
